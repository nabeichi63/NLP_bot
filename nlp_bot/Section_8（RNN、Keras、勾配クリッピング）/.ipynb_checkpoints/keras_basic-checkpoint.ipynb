# %% [markdown]
# # Kerasの基礎
# RNNのコードを学ぶ前に、Kerasの基礎をおさえておきましょう。

# %% [markdown]
# ## 学習用のデータを用意
# 今回は、Kerasに慣れるためにシンプルな学習用のデータを用意します。
# 正解を、サイン関数の値とします。

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# reshapeは配列の形状を変更できる。引数に-1を指定すると、自動で行や列の数が決まる。
x = np.linspace(-np.pi, np.pi).reshape(-1, 1)  # -πからπまで 。linspaceはデフォルトで５０分割なので、50×1のベクトルになる
t = np.sin(x)  # sin関数

print(x.shape)

plt.plot(x, t)
plt.show()
# Out:
# (50, 1)

# %% [markdown]
# ## ニューラルネットワークの構築
# Kerasを使ってニューラルネットワークを構築します。
# Sequential()によりモデルを作成し、addメソッドにより層を追加します。
# Dense()により、通常の層を作ることができます。

# %%
from keras.models import Sequential  # モデルを作成し、add メソッドにより層を追加
from keras.layers import Dense   # Dense()により、通常の層を作ることができる

batch_size = 8  # バッチサイズ
n_in = 1  # 入力層のニューロン数
n_mid = 20  # 中間層のニューロン数
n_out = 1  # 出力層のニューロン数

# 入力層、中間層、出力層の３層のニューラルネットワークを構築
model = Sequential()
model.add(Dense(n_mid, input_shape=(n_in,), activation="sigmoid"))  # 活性化関数にシグモイド関数
model.add(Dense(n_out, activation="linear"))  # 活性化関数に恒等関数。入力のshapeは、最初の層の出力で規定される
model.compile(loss="mean_squared_error", optimizer="sgd")  # 損失関数に二乗誤差、最適化アルゴリズムにSGDを使用してコンパイル
print(model.summary())
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/ichi/anaconda3/envs/nlp_bot/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 20)                40
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 21
# ...
# Total params: 61
# Trainable params: 61
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## 学習
# 構築したモデルを使って、学習を行います。
# 学習にはモデルオブジェクトのfit()メソッドを使います。

# %%
history = model.fit(x, t, batch_size=batch_size, epochs=2000, validation_split=0.1, verbose=0)  # 10%のデータを検証用に使う
# Out:
# WARNING:tensorflow:From /Users/ichi/anaconda3/envs/nlp_bot/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %% [markdown]
# ## 学習の推移
# fit()メソッドが返すオブジェクトを使って、学習の記録を後から確認することができます。

# %%
loss = history.history['loss']  # 訓練用データの誤差
vloss = history.history['val_loss']  # 検証用データの誤差

plt.plot(np.arange(len(loss)), loss)
plt.plot(np.arange(len(vloss)), vloss)
plt.show()

# %% [markdown]
# ## 学習済みモデルの使用
# predict()メソッドにより、学習済みモデルを使用し予測を行うことができます。

# %%
plt.plot(x, model.predict(x))  # モデルを使用し予測を行う
plt.plot(x, t)
plt.show()

# %% [markdown]
# モデルがサイン関数を学習していることが確認できました。
#
# Kerasについて、さらに詳しく知りたい方はこちらの公式ドキュメントを参考にしてください。
# https://keras.io/ja/

# %% [markdown]
# ## 課題
# Kerasでニューラルネットワークを構築し、モデルにコサイン関数を学習させてみましょう。

# %%
x = np.linspace(-np.pi, np.pi).reshape(-1, 1)  # -πからπまで 。linspaceはデフォルトで５０分割なので、50×1のベクトルになる
t = np.cos(x)  # sin関数

print(x.shape)

plt.plot(x, t)
plt.show()
# Out:
# (50, 1)

# %%
from keras.models import Sequential  # モデルを作成し、add メソッドにより層を追加
from keras.layers import Dense   # Dense()により、通常の層を作ることができる

batch_size = 8  # バッチサイズ
n_in = 1  # 入力層のニューロン数
n_mid = 20  # 中間層のニューロン数
n_out = 1  # 出力層のニューロン数

# 入力層、中間層、出力層の３層のニューラルネットワークを構築
modelc = Sequential()
modelc.add(Dense(n_mid, input_shape=(n_in,), activation="sigmoid"))  # 活性化関数にシグモイド関数
modelc.add(Dense(n_out, activation="linear"))  # 活性化関数に恒等関数。入力のshapeは、最初の層の出力で規定される
modelc.compile(loss="mean_squared_error", optimizer="sgd")  # 損失関数に二乗誤差、最適化アルゴリズムにSGDを使用してコンパイル
print(modelc.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 20)                40
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 21
# ...
# Total params: 61
# Trainable params: 61
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
historyc = modelc.fit(x, t, batch_size=batch_size, epochs=2000, validation_split=0.1, verbose=0);  # 10%のデータを検証用に使う

# %%
lossc = historyc.history['loss']  # 訓練用データの誤差
vlossc = historyc.history['val_loss']  # 検証用データの誤差

plt.plot(np.arange(len(lossc)), lossc)
plt.plot(np.arange(len(vlossc)), vlossc)
plt.show()

# %%
plt.plot(x, modelc.predict(x))  # モデルを使用し予測を行う
plt.plot(x, t)
plt.show()
